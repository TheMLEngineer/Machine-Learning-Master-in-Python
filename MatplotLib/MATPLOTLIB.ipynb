# %%
import matplotlib.pyplot as plt

# %%
plt.plot([2,4,6,4])
plt.ylabel('Numbers')
plt.xlabel('Indices')
plt.title('MyPlot')
plt.show()

# %%
'''
X is not given in the above plot so it takes 0,1,2,3 as X
Y is 2,4,6,4
'''
# Out:
# '\nX is not given in the above plot so it takes 0,1,2,3 as X\nY is 2,4,6,4\n'

# %%
#To implement the grid

# %%
plt.plot([1,2,3,4],[1,4,9,16])
plt.xlabel('Numbers')
plt.ylabel('Squares')
plt.grid() #Grid ON

plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16], 'ro') #in 'ro' r -> Red and o-> put dots instead of connecting them
plt.grid()
plt.show()

# %%
import numpy as np

# %%
t = np.arange(0.,5.,0.2)
# t is a np array start with 0 end 5 , step 0.2 till 4.8
'''
b-- means blue dotted line
rs means red squares
g^ means green triangles
plt.legend() gives the --- ^2 square (That whole box)in left top, It makes plot extremely readable.
'''

#Blue dashes red squares and green triangles
plt.plot(t,t**2,'b--',label = '^2') # 'rs' , 'g^'
plt.plot(t,t**2.2,'rs',label = '^2.2')
plt.plot(t,t**2.5,'g^',label = '^2.5')
plt.grid()
plt.legend() #Add legend based on line labels
plt.show()

# %%
x,y = [1,2,3,4],[1,4,9,16]
plt.plot(x,y,linewidth = 5.0)

# %%
x1,y1 = [1,2,3,4],[1,4,9,16]
x2,y2 = [1,2,3,4],[2,4,6,8]
lines = plt.plot(x1,y1,x2,y2)


#Using keyword args
plt.setp(lines[0], color = 'r', linewidth=2.0) # setp means set properties

#Or matlab style String value pairs
plt.step(lines[1],'color','g','linewidth',2.0)
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-745e6d26ade3> in <module>
#       8
#       9 #Or matlab style String value pairs
# ---> 10 plt.step(lines[1],'color','g','linewidth',2.0)
#      11 plt.grid()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\pyplot.py in step(x, y, where, data, *args, **kwargs)
#    2932     return gca().step(
#    2933         x, y, *args, where=where, **({"data": data} if data is not
# -> 2934         None else {}), **kwargs)
#    2935
#    2936
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
# ...

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)
t1 = np.arange(0.0,5.0,0.1)
t2 = np.arange(0.0,5.0,0.02)

plt.figure(1)
#The subplot() command specifies numrows, numcols
# fignum where fignum ranges from 1 to numrows*numcols

plt.subplot(211) # 2 rows, 1 col ,fig 1
plt.grid()
plt.plot(t1,f(t1),'b--')

plt.subplot(212) # 2 rows, 1 col ,fig 2
plt.plot(t2,np.cos(2*np.pi*t2),'r--')
plt.show()

# %%
plt.figure(1) #First fig
plt.subplot(211) # 1st subplot in 1st fig
plt.plot([1,2,3])
plt.subplot(212) # 2nd subplot in 1st fig
plt.plot([4,5,6])


plt.figure(2) # a 2nd fig
plt.plot([4,5,6]) # creates a subplot(111) by default


plt.figure(1) # figure 1 current; subplot(212) still current
plt.subplot(211) #Make subplot(211) in figurel current
plt.title('Easy as 1,2,3') #Subplot(211) title
plt.show()
# Out:
# C:\Users\kmuthu2\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
