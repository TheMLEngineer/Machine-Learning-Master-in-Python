# %%
'''
Packages in python are basically folders 

when it contains __init__.py file it's considered as a package
'''
# Out:
# "\nPackages in python are basically folders \n\nwhen it contains __init__.py file it's considered as a package\n"

# %% [markdown]
# ![title]('img/Package.png')

# %%
from IPython.display import Image
Image(filename='/home/karthikeyan/Documents/1.png')

# %%
'''
Just like how it's mentioned in the image ,
 When a folder has a __init__.py file it's a package, otherwise it's not...
 
 __init__.py can be empty or sometimes contain initialization code
 
'''
# Out:
# "\nJust like how it's mentioned in the image ,\n When a folder has a __init__.py file it's a package, otherwise it's not...\n \n __init__.py can be empty or sometimes contain initialization code\n \n"

# %%
# to access the play.py in sound we use

# %%
# import Game.Sound.play
